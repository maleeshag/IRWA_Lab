# %%
# -*- coding: utf-8 -*-
"""lab_04

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1MC5vJAdVoxXEzFV-NvzQr8s6OpL4HWow
"""

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

document1='the man went out for a walk'
document2='the children sat around the fire'

docs=[document1,document2]

vecs=TfidfVectorizer()

tfidf_mat=vecs.fit_transform(docs)
tfidf_mat

tfidf_mat.toarray()

cs=cosine_similarity(tfidf_mat[0],tfidf_mat[1])
cs

print("Cosine Similarity between Doc2  and Doc1: "+str(cs1[0][0]))
# Out:
# Cosine Similarity between Doc2  and Doc1: 0.9246780984747162

# %% [markdown]
# # Another One

# %%
# -*- coding: utf-8 -*-
"""lab_04

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1MC5vJAdVoxXEzFV-NvzQr8s6OpL4HWow
"""

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

document1='happy happy happy happy happy cat cat cat cat cat cat cat cat cat cat cat cat'
document2='cat cat cat cat happy happy happy'
query = "happy cat"

docs=[document1,document2,query]

vecs=TfidfVectorizer()

tfidf_mat=vecs.fit_transform(docs)
tfidf_mat

tfidf_mat.toarray()

cs1=cosine_similarity(tfidf_mat[0],tfidf_mat[2])
cs2=cosine_similarity(tfidf_mat[1],tfidf_mat[2])




print("Cosine Similarity between Query and Doc1: "+str(cs1[0][0]))
print("Cosine Similarity between Query and Doc2: "+str(cs2[0][0]))
# Out:
# Cosine Similarity between Query and Doc1: 0.9246780984747162
# Cosine Similarity between Query and Doc2: 0.9899494936611666
